# %% [markdown]
# # <font color='darkblue'>*Marina Napoleão - EBAC*</font>
# ## <font color='darkblue'>Projeto Pré Processamento dos Dados - A primeira etapa Pré Modelagem</font>

# %% [markdown]
# # **MÓDULO 14 - Exercício**
# # Pré Processamento dos Dados - A primeira etapa Pré Modelagem

# %% [markdown]
# Para nossa atividade usaremos uma base de churn também, porém essa base não diz respeito a serviços bancários e sim serviços de internet, telefone e tv - Telecomunicação.
#
# Vamos realizar aqui as etapas de limpeza e tratamento de dados vistos durante a aula, porém aplicados a essa base nova.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Lembrem-se sempre de alterar a importação dos dados de acordo com o diretório de vocês.
df = pd.read_csv("CHURN_TELECON_MOD08_TAREFA.csv", delimiter=';')

df.head(10)
# Out:
#    customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0  7590-VHVEG  Female      0    Yes         No                   1
# 1  5575-GNVDE    Male      0     No         No                  34
# 2  3668-QPYBK    Male      0     No         No                   2
# 3  7795-CFOCW    Male      0     No         No                  45
# 4  9237-HQITU     NaN      0     No         No                   2
# 5  9305-CDSKC     NaN      0     No         No                   8
# 6  1452-KIOVK     NaN      0     No        Yes                  22
# 7  6713-OKOMC     NaN      0     No         No                  10
# 8  7892-POOKP     NaN      0    Yes         No                  28
# 9  6388-TABGU     NaN      0     No        Yes                  62
#
#   PhoneService Servico_Internet Servico_Seguranca Suporte_Tecnico StreamingTV  \
# 0           No              DSL                No              No          No
# ...

# %% [markdown]
# Legenda dos dados:
#
# *   **CustomerID** : Esse é o ID único de cada cliente nosso da rede de produtos de telecomunicação.
#
# *   **Genero** : O genero dos nossos clientes.
#
# *   **Idoso** : Se nosso cliente tem acima de 60 anos ou não. (Sim = 1 | Não = 0)
#
# *   **Casado** : Se nosso cliente é casado ou não.
#
# *   **Dependents** : Se cliente tem dependentes.
#
# *   **Tempo_como_Cliente** : Tempo em meses que nosso cliente está com a nossa empresa.
#
# *   **PhoneService** : Se ele contratou serviço telefônico com a nossa empresa.
#
# *   **Servico_Internet** : Qual o tipo de serviço de internet contratado.
#
# *   **Servico_Seguranca** : Se ele contratou serviço de segurança com a nossa empresa.
#
# *   **Suporte_Tecnico** : Se já acionou o suporte técnico.
#
# *   **StreamingTV** : Se ele contratou serviço de streaming para TV.
#
# *   **Tipo_Contrato** : Qual o tipo de contrato dos nossos clientes, se era mensal, anual etc.
#
# *   **Tipo_Contrato** : Qual o tipo de contrato dos nossos clientes, se era mensal, anual etc.
#
# *   **PaymentMethod** : Forma de Pagamento.
#
# *   **Pagamento_Mensal** : Quanto o cliente pagava mensalmente.
#
# *   **Total_Pago** : Total já pago pelo cliente para nossa companhia.
#
# *   **Churn** : Nossa coluna mais importante, se nosso cliente nos abandonou ou não.

# %% [markdown]
# # 1 - Carregue a base, verifique se os tipos de dados estão de acordo com cada coluna e caso não estejam realize a transformação dos tipos de dados.

# %%
#seu código aqui
#verificar qual o tipo de dado de cada coluna.
df.dtypes
# Out:
# customerID             object
# Genero                 object
# Idoso                   int64
# Casado                 object
# Dependents             object
# Tempo_como_Cliente      int64
# PhoneService           object
# Servico_Internet       object
# Servico_Seguranca      object
# Suporte_Tecnico        object
# StreamingTV            object
# Tipo_Contrato          object
# PaymentMethod          object
# Pagamento_Mensal      float64
# Total_Pago            float64
# Churn                  object
# dtype: object

# %%
# 2   Idoso               2500 non-null   int64
df['Idoso'] = df['Idoso'].astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customerID          2500 non-null   object
#  1   Genero              2488 non-null   object
#  2   Idoso               2500 non-null   bool
#  3   Casado              2500 non-null   object
#  4   Dependents          2500 non-null   object
#  5   Tempo_como_Cliente  2500 non-null   int64
#  6   PhoneService        1018 non-null   object
#  7   Servico_Internet    2500 non-null   object
#  8   Servico_Seguranca   2500 non-null   object
#  9   Suporte_Tecnico     2500 non-null   object
#  10  StreamingTV         2500 non-null   object
#  11  Tipo_Contrato       2500 non-null   object
#  12  PaymentMethod       2500 non-null   object
#  13  Pagamento_Mensal    2175 non-null   float64
#  14  Total_Pago          2500 non-null   float64
# ...

# %%
# 15  Churn               2495 non-null   object
df['Churn'] = df['Churn'].astype(object)

# %%
plt.figure(figsize = (12, 4))
sns.histplot(data = df, y = 'Churn', bins = 20, kde = True, color = 'skyblue', orientation = 'vertical')
plt.title('Distribuição de Clientes por Churn')
plt.xlabel('Contagem')
plt.ylabel('Churn')
plt.show()

# %%
df.dropna(subset=['Churn'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2495 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customerID          2495 non-null   object
#  1   Genero              2488 non-null   object
#  2   Idoso               2495 non-null   bool
#  3   Casado              2495 non-null   object
#  4   Dependents          2495 non-null   object
#  5   Tempo_como_Cliente  2495 non-null   int64
#  6   PhoneService        1013 non-null   object
#  7   Servico_Internet    2495 non-null   object
#  8   Servico_Seguranca   2495 non-null   object
#  9   Suporte_Tecnico     2495 non-null   object
#  10  StreamingTV         2495 non-null   object
#  11  Tipo_Contrato       2495 non-null   object
#  12  PaymentMethod       2495 non-null   object
#  13  Pagamento_Mensal    2175 non-null   float64
#  14  Total_Pago          2495 non-null   float64
# ...

# %% [markdown]
# ---------------

# %% [markdown]
# # 2 - Esse exercício faremos por etapas:
# A) Verifique se temos colunas com dados faltantes e traga a % dos dados faltantes por coluna.

# %%
#seu código aqui
df.isnull().values.any()
# Out:
# True

# %%
A = df.isnull().sum()  #Verificando se tem colunas com dados faltantes
print(A,'\n')
B = (df.isnull().sum() / len(df)) * 100  #Trazendo a % dos dados faltantes por coluna.
print('\n', B)
# Out:
# customerID               0
# Genero                   7
# Idoso                    0
# Casado                   0
# Dependents               0
# Tempo_como_Cliente       0
# PhoneService          1482
# Servico_Internet         0
# Servico_Seguranca        0
# Suporte_Tecnico          0
# StreamingTV              0
# Tipo_Contrato            0
# PaymentMethod            0
# Pagamento_Mensal       320
# Total_Pago               0
# Churn                    0
# dtype: int64
#
#
#  customerID             0.000000
# Genero                 0.280561
# Idoso                  0.000000
# Casado                 0.000000
# Dependents             0.000000
# Tempo_como_Cliente     0.000000
# PhoneService          59.398798
# Servico_Internet       0.000000
# Servico_Seguranca      0.000000
# Suporte_Tecnico        0.000000
# StreamingTV            0.000000
# Tipo_Contrato          0.000000
# PaymentMethod          0.000000
# Pagamento_Mensal      12.825651
# Total_Pago             0.000000
# ...

# %% [markdown]
# B) Exclua nessa etapa as linhas das colunas com dados faltantes que você analisar que esse método é o ideal. Justifique o motivo de estar excluindo essas linhas.

# %%
#seu código aqui
df[df['Genero'].isnull()]
# Out:
#     customerID Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 4   9237-HQITU    NaN  False     No         No                   2
# 10  9763-GRSKD    NaN  False    Yes        Yes                  13
# 11  7469-LKBCI    NaN  False     No         No                  16
# 12  8091-TTVAX    NaN  False    Yes         No                  58
# 13  0280-XJGEX    NaN  False     No         No                  49
# 14  5129-JLPIS    NaN  False     No         No                  25
# 15  3655-SNQYZ    NaN  False    Yes        Yes                  69
#
#    PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# 4           Yes      Fiber optic                   No                   No
# 10          Yes              dsl                  Yes                   No
# 11          Yes               No  No internet service  No internet service
# 12          Yes      Fiber optic                   No                   No
# ...

# %%
df.dropna(subset = ['Genero'], inplace = True)

# %%
df['Genero'].isnull().sum()
# Out:
# 0

# %% [markdown]
# * A categoria genero só apresenta 0,28% de dados faltantes, um percentual bem baixo que pode ser excluido.

# %% [markdown]
# C) Nessa etapa substitua pela média, mediana ou moda as linhas das colunas com valores faltantes que você analisou e entendeu que esse era o melhor método. Não se esqueça de justificar sua escolha.

# %% [markdown]
# **Dica variáveis numéricas:** Não se esqueça de verificar a distrbuição dos dados, média e mediana.

# %% [markdown]
# **Dica variáveis categóricas:** Caso precise substituir uma variável categórica utilize um gráfico de barras para verificar a que mais aparece e utilizar ela na substituição.
# Ou você pode optar por excluir a coluna, mas justifique sua escolha.
#
# Caso opte por substituir você pode utilizar a função fillna:
# df['SUACOLUNA'].fillna("VALOR QUE SUBSTITUIRA O NULO", inplace=True)
# Ela funcionará como a replace.

# %%
#seu código aqui
#Substituir pela mediana o 'Pagamento_Mensal'

Pagamento_Mensal_media = df['Pagamento_Mensal'].mean()
Pagamento_Mensal_mediana = df['Pagamento_Mensal'].median()
print('\n Valor da média do Pagamento Mensal:', Pagamento_Mensal_media, '\n Valor da mediana do Pagamento Mensal:', Pagamento_Mensal_mediana)
# Out:
#  Valor da média do Pagamento Mensal: 65.60756321839081
#  Valor da mediana do Pagamento Mensal: 71.45

# %%
sns.set_style('whitegrid')

# Plota o boxplot da coluna de Pagamento_Mensal
plt.figure(figsize = (6, 4))
sns.boxplot(data = df, y = 'Pagamento_Mensal', color = 'skyblue')
plt.title('Boxplot da Coluna Pagamento Mensal')
plt.ylabel('Pagamento_Mensal')
plt.show()

# %%
sns.set_style('darkgrid')

plt.figure(figsize = (12, 6))
sns.histplot(data = df, y = 'Pagamento_Mensal', bins = 20, kde = True, color = 'skyblue')
plt.title('Histograma da Coluna Pagamento Mensal')
plt.xlabel('Pagamento_Mensal')
plt.ylabel('Contagem')
plt.show()

# %%
Pagamento_Mensal_abaixo = df[df['Pagamento_Mensal'] < 130]
Pagamento_Mensal_abaixo['Pagamento_Mensal'].median()
# Out:
# 71.45

# %%
# Substitui os valores faltantes na coluna de salário pela mediana
mediana_Pagamento_Mensal_abaixo = df[df['Pagamento_Mensal'] < 130]['Pagamento_Mensal'].median()

df['Pagamento_Mensal'].fillna(mediana_Pagamento_Mensal_abaixo, inplace = True)

# %%
C = df['Pagamento_Mensal'].isnull().mean()
D = df['Pagamento_Mensal'].median()
print('\n', C, '\n', D)
# Out:
#  0.0
#  71.45

# %% [markdown]
# * A coluna 'Pagamento_Mensal' apresenta 12,8% de valores ausentes. Foi usada a mediana para preencher os valores faltantes, pois ela é menos sensivel a outliers. A mediana dos valores abaixo de 130 foi selecianada para evitar alterações causadas por 'Pagamento_Mensal' muito elevados.

# %%
#Utilizar um gráfico de barras para verificar a que mais aparece e utilizar ela na substituição
#PhoneService
sns.set_style('darkgrid')

plt.figure(figsize = (12, 4))
sns.histplot(data = df, y = 'PhoneService', bins = 20, kde = True, color = 'green')
plt.title('Histograma da Coluna PhoneService')
plt.xlabel('PhoneService')
plt.ylabel('Contagem')
plt.show()

# %%
df['PhoneService'].fillna("No", inplace=True)

# %%
df['PhoneService'].fillna("No", inplace=True)

# %% [markdown]
# * A coluna 'PhoneService' apresenta cerca de 59% de valores ausentes. Ao anlisar os dados, é entendido que os valores ausentes na coluna representa, clientes que não possuem 'PhoneService'. Então, foi preenchido os valores ausentes com a categoria "No".

# %% [markdown]
# ---------------------

# %% [markdown]
# # 3 - Verifique se encontramos valores digitados incorretamente, ou com letras maiusculas ou minusculas, ou até mesmo mesmos valores porém escritos de forma dirente e corrija.

# %%
#seu código aqui
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2488 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customerID          2488 non-null   object
#  1   Genero              2488 non-null   object
#  2   Idoso               2488 non-null   bool
#  3   Casado              2488 non-null   object
#  4   Dependents          2488 non-null   object
#  5   Tempo_como_Cliente  2488 non-null   int64
#  6   PhoneService        2488 non-null   object
#  7   Servico_Internet    2488 non-null   object
#  8   Servico_Seguranca   2488 non-null   object
#  9   Suporte_Tecnico     2488 non-null   object
#  10  StreamingTV         2488 non-null   object
#  11  Tipo_Contrato       2488 non-null   object
#  12  PaymentMethod       2488 non-null   object
#  13  Pagamento_Mensal    2488 non-null   float64
#  14  Total_Pago          2488 non-null   float64
# ...

# %%
# Verificando as variaveis numéricas

E = df['Tempo_como_Cliente'] = df['Tempo_como_Cliente'].astype(int)
F = df['Pagamento_Mensal'] = df['Pagamento_Mensal'].astype(float)
G = df['Total_Pago'] = df['Total_Pago'].astype(float)

print('Valores do tempo como Cliente:', E, '\n Valores do Pagamento Mensal:', F, '\n Valores do Total Pago:', G)
# Out:
# Valores do tempo como Cliente: 0        1
# 1       34
# 2        2
# 3       45
# 16      52
#         ..
# 2495    38
# 2496    18
# 2497     4
# 2498    27
# 2499    41
# Name: Tempo_como_Cliente, Length: 2488, dtype: int32
#  Valores do Pagamento Mensal: 0       29.85
# 1       56.95
# 2       53.85
# 3       71.45
# 16      71.45
#         ...
# 2495    20.25
# 2496    20.05
# 2497    19.60
# 2498    53.80
# 2499    70.20
# Name: Pagamento_Mensal, Length: 2488, dtype: float64
#  Valores do Total Pago: 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 16      1022.95
#          ...
# 2495     814.75
# 2496     388.60
# 2497      93.45
# 2498    1389.85
# 2499    2894.55
# Name: Total_Pago, Length: 2488, dtype: float64

# %%
# Verificando as variaveis tipo 'objeto'

for coluna in df.select_dtypes(include = object):
    print(f'\n coluna: {coluna}')
    print(df[coluna].unique())
# Out:
#  coluna: customerID
# ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '5702-SKUOB' '1134-YWTYF'
#  '6061-GWWAV']
#
#  coluna: Genero
# ['Female' 'Male' 'F' 'M' 'f']
#
#  coluna: Casado
# ['Yes' 'No']
#
#  coluna: Dependents
# ['No' 'Yes']
#
#  coluna: PhoneService
# ['No' 'Yes']
#
#  coluna: Servico_Internet
# ['DSL' 'No' 'Fiber optic' 'dsl']
#
#  coluna: Servico_Seguranca
# ['No' 'Yes' 'No internet service']
#
#  coluna: Suporte_Tecnico
# ['No' 'Yes' 'No internet service']
#
#  coluna: StreamingTV
# ['No' 'No internet service' 'Yes']
#
#  coluna: Tipo_Contrato
# ['Month-to-month' 'One year' 'Two year']
#
#  coluna: PaymentMethod
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
#  coluna: Churn
# ['No' 'Yes']

# %%
for coluna in df.select_dtypes(include = 'object'):
    df[coluna] = df[coluna].str.strip().str.lower()

for coluna in df.select_dtypes(include = object):
    print(f'\n coluna: {coluna}')
    print(df[coluna].unique())
# Out:
#  coluna: customerID
# ['7590-vhveg' '5575-gnvde' '3668-qpybk' ... '5702-skuob' '1134-ywtyf'
#  '6061-gwwav']
#
#  coluna: Genero
# ['female' 'male' 'f' 'm']
#
#  coluna: Casado
# ['yes' 'no']
#
#  coluna: Dependents
# ['no' 'yes']
#
#  coluna: PhoneService
# ['no' 'yes']
#
#  coluna: Servico_Internet
# ['dsl' 'no' 'fiber optic']
#
#  coluna: Servico_Seguranca
# ['no' 'yes' 'no internet service']
#
#  coluna: Suporte_Tecnico
# ['no' 'yes' 'no internet service']
#
#  coluna: StreamingTV
# ['no' 'no internet service' 'yes']
#
#  coluna: Tipo_Contrato
# ['month-to-month' 'one year' 'two year']
#
#  coluna: PaymentMethod
# ['electronic check' 'mailed check' 'bank transfer (automatic)'
#  'credit card (automatic)']
#
#  coluna: Churn
# ['no' 'yes']

# %%
df['Genero'] = df['Genero'].replace({
    'Female': 'female',
    'f': 'female',
    'Male': 'male',
    'm': 'male'
})

for coluna in df.select_dtypes(include = object):
    print(f'\n coluna: {coluna}')
    print(df[coluna].value_counts(dropna = False))
# Out:
#  coluna: customerID
# 7590-vhveg    1
# 9158-vctqb    1
# 8388-dmkae    1
# 4403-bwpay    1
# 9659-qeqsy    1
#              ..
# 1038-zagbi    1
# 6549-nndyt    1
# 3027-ztdho    1
# 0422-ohqhq    1
# 6061-gwwav    1
# Name: customerID, Length: 2488, dtype: int64
#
#  coluna: Genero
# male      1269
# female    1219
# Name: Genero, dtype: int64
#
#  coluna: Casado
# no     1262
# yes    1226
# Name: Casado, dtype: int64
#
#  coluna: Dependents
# no     1705
# yes     783
# Name: Dependents, dtype: int64
#
#  coluna: PhoneService
# no     1568
# yes     920
# Name: PhoneService, dtype: int64
#
#  coluna: Servico_Internet
# fiber optic    1119
# dsl             842
# no              527
# Name: Servico_Internet, dtype: int64
#
#  coluna: Servico_Seguranca
# no                     1254
# yes                     707
# no internet service     527
# Name: Servico_Seguranca, dtype: int64
#
#  coluna: Suporte_Tecnico
# no                     1250
# yes                     711
# ...

# %%
#Verificando a variavel tipo 'bool'
for coluna in df.select_dtypes(include = bool):
    print(f'\n coluna: {coluna}')
    print(df[coluna].unique())
# Out:
#  coluna: Idoso
# [False  True]

# %% [markdown]
# ----------------

# %% [markdown]
# # [EXTRA] 4 - Caso deseje, para manter um padrão na sua base, renomeie as colunas ou deixando em português, ou inglês.

# %%
df.columns = ['ID_Cliente','Genero', 'Idoso', 'Casado', 'Dependentes', 'Tempo_como_Cliente', 'Servico_Telefone', 'Sevico_Internet', 'Sevico_Seguranca', 'Suporte_Tecnico', 'StreamingTV', 'Tipo_Contrato', 'Metodo_Pagamento', 'Pagamento_Mensal', 'Total_Pago', 'Churn']
df.head(5)
# Out:
#     ID_Cliente  Genero  Idoso Casado Dependentes  Tempo_como_Cliente  \
# 0   7590-vhveg  female  False    yes          no                   1
# 1   5575-gnvde    male  False     no          no                  34
# 2   3668-qpybk    male  False     no          no                   2
# 3   7795-cfocw    male  False     no          no                  45
# 16  8191-xwszg  female  False     no          no                  52
#
#    Servico_Telefone Sevico_Internet     Sevico_Seguranca      Suporte_Tecnico  \
# 0                no             dsl                   no                   no
# 1               yes             dsl                  yes                   no
# 2               yes             dsl                  yes                   no
# 3                no             dsl                  yes                  yes
# 16              yes              no  no internet service  no internet service
#
#             StreamingTV   Tipo_Contrato           Metodo_Pagamento  \
# ...

# %%
df.to_csv("CHURN_TELECON_MOD08_TAREFA_ATIVIDADE_MOD15.csv", index = False)

# %% [markdown]
# -----------
